# %% [markdown]
# # Assignment 2

# %% [markdown]
# 00You only need to write one line of code for each question. When answering questions that ask you to identify or interpret something, the length of your response doesn’t matter. For example, if the answer is just ‘yes,’ ‘no,’ or a number, you can just give that answer without adding anything else.
#
# We will go through comparable code and concepts in the live learning session. If you run into trouble, start by using the help `help()` function in Python, to get information about the datasets and function in question. The internet is also a great resource when coding (though note that **no outside searches are required by the assignment!**). If you do incorporate code from the internet, please cite the source within your code (providing a URL is sufficient).
#
# Please bring questions that you cannot work out on your own to office hours, work periods or share with your peers on Slack. We will work with you through the issue.

# %% [markdown]
# ### Linear Regression
#
# Let's set up our workspace and use the **Auto MPG dataset**. This dataset contains several features (such as horsepower, weight, displacement, and acceleration) and a target variable indicating the car's **miles per gallon (MPG)**.
#
# Here, we will model **MPG (continuous outcome)** based on the car's physical and performance characteristics.

# %%
# Import standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
import seaborn as sns

# Load the Auto MPG dataset
mpg_data = sns.load_dataset('mpg')

# Drop rows with missing values
mpg_data = mpg_data.dropna(subset=['mpg', 'horsepower', 'weight', 'displacement'])

# Display the DataFrame
mpg_data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# #### **Question 1:**
# #### Data inspection
#
# Before fitting any model, it is essential to understand our data. **Use Python code** to answer the following questions about the **Auto MPG dataset**:
#
# _(i)_ How many observations (rows) does the dataset contain and also how many variables (columns) does the dataset contain?

# %%
# To get the number of observation and variables (columns) of the dataset, I use the following
num_observations = mpg_data.shape[0]
num_variables = mpg_data.shape[1]
print('The dataset contains {} observations (rows) and {} variables (columns).'.format(num_observations, num_variables))
# Out:
# The dataset contains 392 observations (rows) and 9 variables (columns).

# %% [markdown]
# _(ii)_ What is the 'variable type' of the response variable `mpg` (e.g., 'integer', 'category', etc.) and explain what it is in short? (1-2 sentences at max)

# %%
# To check the data type of the 'mpg' variable
mpg_dtype = mpg_data['mpg'].dtype
print('The data type of the response variable is: {}'.format(mpg_dtype))
# Out:
# The data type of the response variable is: float64

# %% [markdown]
# Your explanation...

# %% [markdown]
# _(iii)_ Find the 5 rows with the greatest `horsepower`.

# %%
# To find the 5 rows with the greatest `horsepower, sort the dataset by the `horsepower in descending order 
# Then , select the 5 rows with the greatest `horsepower'
high_5_horsepower = mpg_data.sort_values(by= 'horsepower', ascending = False).head(5)
high_5_horsepower
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 116  16.0          8         400.0       230.0    4278           9.5
# 95   12.0          8         455.0       225.0    4951          11.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
#
#      model_year origin                      name
# 116          73    usa        pontiac grand prix
# 95           73    usa  buick electra 225 custom
# 13           70    usa   buick estate wagon (sw)
# 8            70    usa          pontiac catalina
# 6            70    usa          chevrolet impala

# %% [markdown]
# _(iv)_ How many predictor variables do we have (Hint: all variables other than `mpg`)?

# %%
# To compute the number of predictor variables, count the number of columns in the dataset
# Then, exclude the resposne variable column 'mpg' to get the predictor variable
total_variables = mpg_data.shape[1]
pred_variables = total_variables - 1
print('The dataset contains {} predictor variables.'.format(pred_variables))
# Out:
# The dataset contains 8 predictor variables.

# %% [markdown]
# You can use `print()` and `describe()` to help answer these questions.

# %% [markdown]
# #### **Question 2:**
# #### Data-visualization
#
# Before we fit and review model outputs, we should visualize our data. Review the code and plot, shown below.

# %%
# Exclude the 'mpg' (target variable) and non-numeric columns from the feature names
feature_names = mpg_data.select_dtypes(include=[float, int]).columns.difference(['mpg'])

# Loop through each numeric feature (column) in mpg_data
for feature in feature_names:
    # Extract the feature column and target variable (mpg)
    X_feature = mpg_data[[feature]].values  # Extract as a 2D array
    y = mpg_data['mpg'].values  # Target variable (mpg)
    
    # Create a scatter plot for the feature against the target (mpg)
    plt.figure(figsize=(6, 4))
    plt.scatter(X_feature, y, label='Data', color='blue')

    # Fit a linear regression model
    lm = LinearRegression()
    lm.fit(X_feature, y)

    # Plot the regression line
    plt.plot(X_feature, lm.predict(X_feature), color='red', label='Regression Line')

    # Add labels and title
    plt.xlabel(feature)
    plt.ylabel('Miles Per Gallon')
    plt.title(f'{feature} vs Miles Per Gallon')

    # Add a legend
    plt.legend()

    # Show the plot
    plt.show()

# %% [markdown]
# Answer the following questions:
#
# _(i)_ Describe the associations being plotted ? (i.e., positive association, negative association, no association)

# %% [markdown]
# > The scatter plot and the regression lines generated by the code above revealed the type and strenth of the association between each numeric predictor variable and the target variable 'mpg (miles per gallon)'.
# 1. Acceleration vs mpg
# - positive association
#
# 2. Cylinders vs mpg
# - Negative association
#
# 3. displacement vs mpg
# - Negative association
#
# 4. horsepower vs mpg
# - Negative association
#
# 5. model year vs mpg
# - Positive association
#
# 6. Weight vs mpg
# - Negative association

# %% [markdown]
# _(ii)_ What concept ‘defines’ the plotted line?

# %% [markdown]
# >> The scatter plot and the regression lines generated by the code above revealed the type and strenth of the association between each numeric predictor variable and the target variable 'mpg (miles per gallon)'.
# 1. Acceleration vs mpg
# - Cars with higher acceleration tend to have more efficient engines, which may slightly correlete with better fuel efficiency (mpg). Moreover, the relationshop is typically weak.
#
# 2. Cylinders vs mpg
# - Cars with more cylinders usually have larger power engine, leading to higher fuel consumption and lower mpg
#
# 3. displacement vs mpg
# - Larger engine displacement (engine size) generally indicates higher fuel consumption, resulting in lower mpg. Cars with larger engines, typically prioritize power over fuel efficiency.
#
# 4. horsepower vs mpg
# - Cars with higher horsepower (more powerful engines) tend to consume more fuel, leading to lower mpg. The relationship may not be perfectly linear as some higher-performance cars are desighed to balce power and efficiency.
#
# 5. model year vs mpg
# - Newer cars (higher model years) generally incorporate advancements in fuel efficiency, So mpg tends to imrpove with newer model years.
#
# 6. Weight vs mpg
# - Heavier cars typically consumes more fuel reducing efficiency,. As the weight of a car increases, its mph decreases significantly.

# %% [markdown]
# _(iii)_ Do all data points in the dataset fall perfectly along the plotted line? If not, why might there be deviations between the data points and the line, and what do these deviations indicate about the relationship between the variables?

# %% [markdown]
# >
# 1. Acceleration vs mpg
# - The scatter points may show a slight upward trend and the regression line have a positive slope.
#
# 2. Cylinders vs mpg
# - A downward trend in the scatter points, with a negative slope.
#
# 3. displacement vs mpg
# - A clear downward trend in the scatter points and a regression line with negative slope.
#
# 4. horsepower vs mpg
# - A downward trend in the scatter points and a regression line with negative slope with a moderate steep regression line.
#
# 5. model year vs mpg
# - An upward trend in the scatter points and a regression line with positive slope.
#
# 6. Weight vs mpg
# - The scatter points show a clear wownward trend, and the regression line have a steep negative slope.

# %% [markdown]
# #### **Question 3:**
# #### Model fit
# Now, let’s fit a multivariable linear regression model using the general syntax `lm()`. As above, use **mpg** as the response variable **Y**, and all other variables as the predictors.
#
# **Step 1: Split the dataset into train and test sets, using a 75-25 split. (use random_state=42)**

# %%
# split the dataset into train and test sets of 75-25 ratio
# Define the datasets features (X_data) and the target (Y_data) variables
X_data = mpg_data.drop(columns=['mpg'])
Y_data = mpg_data['mpg']

# Now split the dataset into train (75%) and test )25%( sets with random states = 41
X_train, X_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=25, random_state=42)
print('Training set size: {} samples'.format(X_train.shape[0]))
print('Test set size: {} samples'.format(X_test.shape[0]))
# Out:
# Training set size: 367 samples
# Test set size: 25 samples

# %% [markdown]
# **Step 2: Fit the linear regression model.**

# %%
# Your code here ...
numeric_predictors = X_train.select_dtypes(include=['float', 'int'])

# Fit the linear regression model using the training data
lm = LinearRegression()
lm.fit(numeric_predictors, y_train)


# Create a DataFrame containing the slope (coefficients) and intercept
coefficients_df = pd.DataFrame({
    "predictor": numeric_predictors.columns,
    "slope": lm.coef_,
    "intercept": [lm.intercept_] * len(lm.coef_)
})

# Display the coefficients DataFrame
print(coefficients_df)

# lm.coef_ gives the coefficients for each predictor (change in miles per gallon per unit change in each predictor variable)
# lm.intercept_ gives the intercept b_0 (the predicted miles per gallon when all predictors are set to 0)
# Out:
#       predictor     slope  intercept
# 0     cylinders -0.235480 -15.173114
# 1  displacement  0.001906 -15.173114
# 2    horsepower  0.003659 -15.173114
# 3        weight -0.006485 -15.173114
# 4  acceleration  0.065073 -15.173114
# 5    model_year  0.756051 -15.173114

# %% [markdown]
# #### **Question 4:**
# #### RMSPE
# **Step 3. Finally, we predict on the test data set to assess how well our model does.**
#
# We will evaluate our final model's test error measured by RMSPE.

# %%
# Ensure predictors are numeric in the test set also like the training set
X_test_numeric_predictors = X_test.select_dtypes(include = ['float', 'int'])
# Now make a prediction on the test set
y_prediction = lm.predict(X_test_numeric_predictors)

# To compute RMSE, compute MSE first using sklearn library
mse = mean_squared_error(y_test, y_prediction)
# Now compute RMSE
rmse = np.sqrt(mse)
print('The root mean squared error (RMSE) is: %.3f' % rmse)
# Out:
# The root mean squared error (RMSE) is: 3.458

# %% [markdown]
# # Criteria
#
# | **Criteria**                                           | **Complete**                                      | **Incomplete**                                    |
# |--------------------------------------------------------|---------------------------------------------------|--------------------------------------------------|
# | **Data Inspection**                                    | Data is inspected for the number of variables, observations, and data types. | Data inspection is missing or incomplete.         |
# | **Data Visualization**                                 | Visualizations (e.g., scatter plots, histograms) are properly interepreted to explore the relationships between variables. | Data visualization were not correctly interpreted. |
# | **Model Initialization**                               | The linear regression model is correctly initialized.            | The linear regression model is not initialized or is incorrect. |
# | **Model Evaluation on Test Data**                      | The model is evaluated on the test data using appropriate metrics (e.g., RMSE). | The model evaluation is missing or uses the wrong metric. |

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Note:
#
# If you like, you may collaborate with others in the cohort. If you choose to do so, please indicate with whom you have worked with in your pull request by tagging their GitHub username. Separate submissions are required.
#
# ### Submission Parameters:
# * Submission Due Date: `11:59 PM - 01/19/2025`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/LCR/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-4-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
